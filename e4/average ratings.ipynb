# %%
import pandas as pd
import difflib

movieRatings = pd.read_csv('movie_ratings.csv')
movie_listdf = pd.read_table('movie_list.txt')
movie_list = movie_listdf['13th'].shift(1)
movie_list.iloc[0] = '13th'
mvf = movie_list.apply(lambda x: difflib.get_close_matches(x, movieRatings['title']))

def getRating(movie_title):
    arr = movieRatings.loc[movieRatings['title'] == movie_title]['rating'].values
    if len(arr)< 1:
        return 0
    return arr[0]

# %%
mvfs = mvf.apply(lambda x: pd.Series(x))
tmpRatings = mvfs.applymap(getRating)
avgRatings = tmpRatings.mean(axis=1).round(2)

# %%
output = pd.DataFrame({'title' : movie_list, 'ratings' : avgRatings})
output = output[['title', 'ratings']]
output
# Out:
#                                       title  ratings
# 0                                      13th     9.00
# 1                                        42     7.00
# 2           Abraham Lincoln: Vampire Hunter     6.00
# 3                       Alice in Wonderland     5.33
# 4                          Arthur Christmas     5.67
# 5                             Before Sunset     7.00
# 6                      Bridget Jones's Baby     6.67
# 7                                 Cape Fear     7.00
# 8                                      Cars     8.33
# 9                   Cobain: Montage of Heck     8.33
# 10                               Contraband     5.00
# 11                       Dead Poets Society     9.00
# 12                                 Defiance     8.00
# 13                             Delivery Man     3.00
# 14                                    Drive     7.00
# 15                            Eat Pray Love     2.00
# 16                                  Flipped     5.33
# 17                Forgetting Sarah Marshall     7.67
# 18                                 Hercules     7.00
# 19                                If I Stay     6.00
# 20                               Iron Man 3    10.00
# 21                          Just Go with It     7.00
# 22                  Kari-gurashi no Arietti     8.33
# 23                            Kung Fu Panda     6.00
# 24                           Les Misérables     9.00
# 25                       Me, Myself & Irene     6.33
# 26                            Moulin Rouge!     8.00
# 27                               Mr. Turner     6.67
# 28  Night at the Museum: Secret of the Tomb     5.67
# 29                           Reservoir Dogs     7.00
# 30                                     Rush     8.00
# 31                                   Solace    10.00
# 32                                      Spy     8.00
# 33                                    Ted 2     8.00
# 34       Terminator 3: Rise of the Machines     6.67
# 35                            The Big Short     7.00
# 36                      The Bourne Identity     8.00
# 37                   The Day After Tomorrow     8.00
# 38                 The Fast and the Furious     5.33
# 39                  The Fate of the Furious     7.00
# 40                               The Others     9.33
# 41                              The Rewrite     5.67
# 42                        The Thin Red Line     3.67
# 43                           The Ugly Truth     7.67
# 44                  The Wolf of Wall Street     8.00
# 45                                     Thor     3.00
# 46                             Total Recall     8.00
# 47                           Tropic Thunder     8.00
# 48        Who Am I - Kein System ist sicher     6.00
